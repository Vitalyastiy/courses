# %%
import folium 
import pandas as pd
from folium.plugins import MarkerCluster
import pandas as pd
import requests
from xml.etree import ElementTree
import numpy as np
import folium
import numpy as np

# %%
df1= pd.read_excel(r"C:\Users\vitaly.flerin\Desktop\05 Ad hoc\2022-12-01_гео\yan_1.xlsx")
df1
# Out:
#         id create_date       subs_id  \
# 0        1  2022-02-12  100071156888
# 1        2  2022-07-27  100072087061
# 2        3  2022-04-12  100056305839
# 3        4  2022-08-31  100034687577
# 4        5  2022-08-02  100061132577
# ...    ...         ...           ...
# 2989  2990  2022-07-13      14571832
# 2990  2991  2022-03-31  200081992824
# 2991  2992  2022-04-05  200026153428
# 2992  2993  2022-09-28  200074500228
# 2993  2994  2022-01-28  200090732985
#
#                                                 address       lat        lng  \
# 0                 город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1                       город ВЛАДИВОСТОК улица  дом 10   0.00000    0.00000
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 3     город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 4     город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# ...                                                 ...       ...        ...
# 2989        город САНКТ-ПЕТЕРБУРГ улица ШИШКИНА дом 127  60.08880   30.28261
# 2990         город САНКТ-ПЕТЕРБУРГ улица ШОТМАНА дом 14  59.90207   30.48099
# 2991        город САНКТ-ПЕТЕРБУРГ улица ЩЕРБАКОВА дом 3  60.02922   30.30067
# 2992        город САНКТ-ПЕТЕРБУРГ улица ЭНГЕЛЬСА дом 95  59.83305   30.10156
# 2993        город САНКТ-ПЕТЕРБУРГ улица ЯХТЕННАЯ дом 35  60.00728   30.22749
#
#                                          Yandex_address
# 0     Русская улица, 61, Владивосток, Приморский кра...
# 1                                                     0
# 2     улица Адмирала Горшкова, 36, микрорайон Снегов...
# 3     улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 4     улица Адмирала Кузнецова, 66, Владивосток, При...
# ...                                                 ...
# 2989  улица Шишкина, 127, посёлок Парголово, Санкт-П...
# 2990         улица Шотмана, 14, Санкт-Петербург, Россия
# 2991      улица Щербакова, 3к1, Санкт-Петербург, Россия
# 2992  улица Энгельса, территория Сергиево, Санкт-Пет...
# 2993        Яхтенная улица, 35, Санкт-Петербург, Россия
#
# [2994 rows x 7 columns]

# %%
df2= pd.read_excel(r"C:\Users\vitaly.flerin\Desktop\05 Ad hoc\2022-12-01_гео\yan_2.xlsx")
df2
# Out:
#         id create_date       subs_id  \
# 0        1  2022-01-10  200031352457
# 1        2  2022-01-10      23205690
# 2        3  2022-01-10      24741862
# 3        4  2022-01-10      58834929
# 4        5  2022-01-10  300052524038
# ...    ...         ...           ...
# 8585  8586  2022-05-23  100041271746
# 8586  8587  2022-05-23  100066896480
# 8587  8588  2022-05-23  100033136764
# 8588  8589  2022-05-23  100077186785
# 8589  8590  2022-05-23  200081681365
#
#                                                    addr       lat        lng  \
# 0      город АРХАНГЕЛЬСК проспект ЛЕНИНГРАДСКИЙ дом 358  64.49131   40.71500
# 1                  город БАТАЙСК улица ЭНГЕЛЬСА дом 131  47.14592   39.74894
# 2     город БЕЛГОРОД район БЕЛГОРОДСКИЙ массив РАЗУМ...  50.56896   36.76310
# 3                  город БЕЛГОРОД улица ЕСЕНИНА дом 40А  50.55853   36.55969
# 4                        город ВОРОНЕЖ улица ПЯТНИЦКОГО  51.66781   39.21378
# ...                                                 ...       ...        ...
# 8585               город ЧЕЛЯБИНСК улица ПОБЕДЫ дом 31В  55.18061   61.46042
# 8586              город ЧЕЛЯБИНСК улица САЛЮТНАЯ дом 52  55.16914   61.43617
# 8587             город ЧЕЛЯБИНСК улица УРАЛЬСКАЯ дом 23  55.12447   61.50254
# 8588               город ЧЕРЕМХОВО улица КИРОВО дом 112  53.16049  103.06209
# 8589            город ЯРОСЛАВЛЬ шоссе ТУТАЕВСКОЕ дом 24  57.67746   39.83770
#
#                                          Yandex_address
# 0      Ленинградский проспект, 358, Архангельск, Россия
# 1     улица Энгельса, 131, Батайск, Ростовская облас...
# 2     микрорайон Разумное-71, посёлок городского тип...
# 3                  улица Есенина, 40А, Белгород, Россия
# 4                     улица Пятницкого, Воронеж, Россия
# ...                                                 ...
# 8585                улица Победы, 37, Челябинск, Россия
# 8586              Салютная улица, 52, Челябинск, Россия
# 8587             Уральская улица, 23, Челябинск, Россия
# 8588  улица Кирова, 112, Черемхово, Иркутская област...
# 8589            Тутаевское шоссе, 24, Ярославль, Россия
#
# [8590 rows x 7 columns]

# %%
df2= df2.rename(columns={'addr': 'address'})
df2
# Out:
#         id create_date       subs_id  \
# 0        1  2022-01-10  200031352457
# 1        2  2022-01-10      23205690
# 2        3  2022-01-10      24741862
# 3        4  2022-01-10      58834929
# 4        5  2022-01-10  300052524038
# ...    ...         ...           ...
# 8585  8586  2022-05-23  100041271746
# 8586  8587  2022-05-23  100066896480
# 8587  8588  2022-05-23  100033136764
# 8588  8589  2022-05-23  100077186785
# 8589  8590  2022-05-23  200081681365
#
#                                                 address       lat        lng  \
# 0      город АРХАНГЕЛЬСК проспект ЛЕНИНГРАДСКИЙ дом 358  64.49131   40.71500
# 1                  город БАТАЙСК улица ЭНГЕЛЬСА дом 131  47.14592   39.74894
# 2     город БЕЛГОРОД район БЕЛГОРОДСКИЙ массив РАЗУМ...  50.56896   36.76310
# 3                  город БЕЛГОРОД улица ЕСЕНИНА дом 40А  50.55853   36.55969
# 4                        город ВОРОНЕЖ улица ПЯТНИЦКОГО  51.66781   39.21378
# ...                                                 ...       ...        ...
# 8585               город ЧЕЛЯБИНСК улица ПОБЕДЫ дом 31В  55.18061   61.46042
# 8586              город ЧЕЛЯБИНСК улица САЛЮТНАЯ дом 52  55.16914   61.43617
# 8587             город ЧЕЛЯБИНСК улица УРАЛЬСКАЯ дом 23  55.12447   61.50254
# 8588               город ЧЕРЕМХОВО улица КИРОВО дом 112  53.16049  103.06209
# 8589            город ЯРОСЛАВЛЬ шоссе ТУТАЕВСКОЕ дом 24  57.67746   39.83770
#
#                                          Yandex_address
# 0      Ленинградский проспект, 358, Архангельск, Россия
# 1     улица Энгельса, 131, Батайск, Ростовская облас...
# 2     микрорайон Разумное-71, посёлок городского тип...
# 3                  улица Есенина, 40А, Белгород, Россия
# 4                     улица Пятницкого, Воронеж, Россия
# ...                                                 ...
# 8585                улица Победы, 37, Челябинск, Россия
# 8586              Салютная улица, 52, Челябинск, Россия
# 8587             Уральская улица, 23, Челябинск, Россия
# 8588  улица Кирова, 112, Черемхово, Иркутская област...
# 8589            Тутаевское шоссе, 24, Ярославль, Россия
#
# [8590 rows x 7 columns]

# %%
df1
# Out:
#         id create_date       subs_id  \
# 0        1  2022-02-12  100071156888
# 1        2  2022-07-27  100072087061
# 2        3  2022-04-12  100056305839
# 3        4  2022-08-31  100034687577
# 4        5  2022-08-02  100061132577
# ...    ...         ...           ...
# 2989  2990  2022-07-13      14571832
# 2990  2991  2022-03-31  200081992824
# 2991  2992  2022-04-05  200026153428
# 2992  2993  2022-09-28  200074500228
# 2993  2994  2022-01-28  200090732985
#
#                                                 address       lat        lng  \
# 0                 город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1                       город ВЛАДИВОСТОК улица  дом 10   0.00000    0.00000
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 3     город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 4     город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# ...                                                 ...       ...        ...
# 2989        город САНКТ-ПЕТЕРБУРГ улица ШИШКИНА дом 127  60.08880   30.28261
# 2990         город САНКТ-ПЕТЕРБУРГ улица ШОТМАНА дом 14  59.90207   30.48099
# 2991        город САНКТ-ПЕТЕРБУРГ улица ЩЕРБАКОВА дом 3  60.02922   30.30067
# 2992        город САНКТ-ПЕТЕРБУРГ улица ЭНГЕЛЬСА дом 95  59.83305   30.10156
# 2993        город САНКТ-ПЕТЕРБУРГ улица ЯХТЕННАЯ дом 35  60.00728   30.22749
#
#                                          Yandex_address
# 0     Русская улица, 61, Владивосток, Приморский кра...
# 1                                                     0
# 2     улица Адмирала Горшкова, 36, микрорайон Снегов...
# 3     улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 4     улица Адмирала Кузнецова, 66, Владивосток, При...
# ...                                                 ...
# 2989  улица Шишкина, 127, посёлок Парголово, Санкт-П...
# 2990         улица Шотмана, 14, Санкт-Петербург, Россия
# 2991      улица Щербакова, 3к1, Санкт-Петербург, Россия
# 2992  улица Энгельса, территория Сергиево, Санкт-Пет...
# 2993        Яхтенная улица, 35, Санкт-Петербург, Россия
#
# [2994 rows x 7 columns]

# %%
df1['Yandex_address'] = df1['Yandex_address'].astype(str)

# %%
df1 = df1[(df1['Yandex_address'].str.contains('Россия'))]
df1
# Out:
#         id create_date       subs_id  \
# 0        1  2022-02-12  100071156888
# 2        3  2022-04-12  100056305839
# 3        4  2022-08-31  100034687577
# 4        5  2022-08-02  100061132577
# 5        6  2022-11-01  100060041431
# ...    ...         ...           ...
# 2989  2990  2022-07-13      14571832
# 2990  2991  2022-03-31  200081992824
# 2991  2992  2022-04-05  200026153428
# 2992  2993  2022-09-28  200074500228
# 2993  2994  2022-01-28  200090732985
#
#                                                 address       lat        lng  \
# 0                 город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 3     город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 4     город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 5     город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                 ...       ...        ...
# 2989        город САНКТ-ПЕТЕРБУРГ улица ШИШКИНА дом 127  60.08880   30.28261
# 2990         город САНКТ-ПЕТЕРБУРГ улица ШОТМАНА дом 14  59.90207   30.48099
# 2991        город САНКТ-ПЕТЕРБУРГ улица ЩЕРБАКОВА дом 3  60.02922   30.30067
# 2992        город САНКТ-ПЕТЕРБУРГ улица ЭНГЕЛЬСА дом 95  59.83305   30.10156
# 2993        город САНКТ-ПЕТЕРБУРГ улица ЯХТЕННАЯ дом 35  60.00728   30.22749
#
#                                          Yandex_address
# 0     Русская улица, 61, Владивосток, Приморский кра...
# 2     улица Адмирала Горшкова, 36, микрорайон Снегов...
# 3     улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 4     улица Адмирала Кузнецова, 66, Владивосток, При...
# 5     улица Адмирала Кузнецова, 74, Владивосток, При...
# ...                                                 ...
# 2989  улица Шишкина, 127, посёлок Парголово, Санкт-П...
# 2990         улица Шотмана, 14, Санкт-Петербург, Россия
# 2991      улица Щербакова, 3к1, Санкт-Петербург, Россия
# 2992  улица Энгельса, территория Сергиево, Санкт-Пет...
# 2993        Яхтенная улица, 35, Санкт-Петербург, Россия
#
# [2987 rows x 7 columns]

# %%
df2['Yandex_address'] = df2['Yandex_address'].astype(str)

# %%
df2 = df2[(df2['Yandex_address'].str.contains('Россия'))]
df2
# Out:
#         id create_date       subs_id  \
# 0        1  2022-01-10  200031352457
# 1        2  2022-01-10      23205690
# 2        3  2022-01-10      24741862
# 3        4  2022-01-10      58834929
# 4        5  2022-01-10  300052524038
# ...    ...         ...           ...
# 8585  8586  2022-05-23  100041271746
# 8586  8587  2022-05-23  100066896480
# 8587  8588  2022-05-23  100033136764
# 8588  8589  2022-05-23  100077186785
# 8589  8590  2022-05-23  200081681365
#
#                                                 address       lat        lng  \
# 0      город АРХАНГЕЛЬСК проспект ЛЕНИНГРАДСКИЙ дом 358  64.49131   40.71500
# 1                  город БАТАЙСК улица ЭНГЕЛЬСА дом 131  47.14592   39.74894
# 2     город БЕЛГОРОД район БЕЛГОРОДСКИЙ массив РАЗУМ...  50.56896   36.76310
# 3                  город БЕЛГОРОД улица ЕСЕНИНА дом 40А  50.55853   36.55969
# 4                        город ВОРОНЕЖ улица ПЯТНИЦКОГО  51.66781   39.21378
# ...                                                 ...       ...        ...
# 8585               город ЧЕЛЯБИНСК улица ПОБЕДЫ дом 31В  55.18061   61.46042
# 8586              город ЧЕЛЯБИНСК улица САЛЮТНАЯ дом 52  55.16914   61.43617
# 8587             город ЧЕЛЯБИНСК улица УРАЛЬСКАЯ дом 23  55.12447   61.50254
# 8588               город ЧЕРЕМХОВО улица КИРОВО дом 112  53.16049  103.06209
# 8589            город ЯРОСЛАВЛЬ шоссе ТУТАЕВСКОЕ дом 24  57.67746   39.83770
#
#                                          Yandex_address
# 0      Ленинградский проспект, 358, Архангельск, Россия
# 1     улица Энгельса, 131, Батайск, Ростовская облас...
# 2     микрорайон Разумное-71, посёлок городского тип...
# 3                  улица Есенина, 40А, Белгород, Россия
# 4                     улица Пятницкого, Воронеж, Россия
# ...                                                 ...
# 8585                улица Победы, 37, Челябинск, Россия
# 8586              Салютная улица, 52, Челябинск, Россия
# 8587             Уральская улица, 23, Челябинск, Россия
# 8588  улица Кирова, 112, Черемхово, Иркутская област...
# 8589            Тутаевское шоссе, 24, Ярославль, Россия
#
# [8462 rows x 7 columns]

# %%
df_f = pd.concat([df1, df2], ignore_index=True)
df_f
# Out:
#          id create_date       subs_id  \
# 0         1  2022-02-12  100071156888
# 1         3  2022-04-12  100056305839
# 2         4  2022-08-31  100034687577
# 3         5  2022-08-02  100061132577
# 4         6  2022-11-01  100060041431
# ...     ...         ...           ...
# 11444  8586  2022-05-23  100041271746
# 11445  8587  2022-05-23  100066896480
# 11446  8588  2022-05-23  100033136764
# 11447  8589  2022-05-23  100077186785
# 11448  8590  2022-05-23  200081681365
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 11444               город ЧЕЛЯБИНСК улица ПОБЕДЫ дом 31В  55.18061   61.46042
# 11445              город ЧЕЛЯБИНСК улица САЛЮТНАЯ дом 52  55.16914   61.43617
# 11446             город ЧЕЛЯБИНСК улица УРАЛЬСКАЯ дом 23  55.12447   61.50254
# 11447               город ЧЕРЕМХОВО улица КИРОВО дом 112  53.16049  103.06209
# 11448            город ЯРОСЛАВЛЬ шоссе ТУТАЕВСКОЕ дом 24  57.67746   39.83770
#
#                                           Yandex_address
# 0      Русская улица, 61, Владивосток, Приморский кра...
# 1      улица Адмирала Горшкова, 36, микрорайон Снегов...
# 2      улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 3      улица Адмирала Кузнецова, 66, Владивосток, При...
# 4      улица Адмирала Кузнецова, 74, Владивосток, При...
# ...                                                  ...
# 11444                улица Победы, 37, Челябинск, Россия
# 11445              Салютная улица, 52, Челябинск, Россия
# 11446             Уральская улица, 23, Челябинск, Россия
# 11447  улица Кирова, 112, Черемхово, Иркутская област...
# 11448            Тутаевское шоссе, 24, Ярославль, Россия
#
# [11449 rows x 7 columns]

# %%
df_np = pd.read_csv(r"C:\Users\vitaly.flerin\Desktop\05 Ad hoc\2022-12-01_гео\result_2.csv",sep=',' , encoding='cp1251' )
df_np
# Out:
#        create_date       subs_id  \
# 0       2022-09-14  300002341055
# 1       2022-11-03  200102964910
# 2       2022-07-19      46541013
# 3       2022-04-04      62082420
# 4       2022-01-31  200073346869
# ...            ...           ...
# 181747  2022-04-18      59625814
# 181748  2022-07-21  200052041366
# 181749  2022-10-11  200085763712
# 181750  2022-01-26      51783545
# 181751  2022-02-18  200080096773
#
#                                                    mark_6          Region  nps
# 0       У вас есть запись разговоров вот и смотрите ни...           Пермь   -1
# 1       На все вопросы сотрудники отвечали доступно, п...       Сыктывкар    1
# 2       Ростовская обл цимлянский район ст красноярска...  Ростов на Дону   -1
# 3                                        Спасибо вам тоже       Волгоград    1
# 4       Частный дом в Калужской обл. Перемышльского ро...          Калуга   -1
# ...                                                   ...             ...  ...
# 181747                                          Благодарю       Волгоград    1
# 181748                         Иногда по всему Ульяновску       Ульяновск   -1
# 181749                                   Посёлок Батецкий      В.Новгород   -1
# 181750                     Добринский район Липецкой обл.          Липецк   -1
# 181751                           Хорошая связь и интернет       Ярославль    1
#
# [181752 rows x 5 columns]

# %%
df_pivot = pd.merge(df_f, df_np, how = 'inner', left_on = ['create_date', 'subs_id'], right_on = ['create_date', 'subs_id'])
df_pivot
#df_np['create_date'] = df['create_date'].astype(object)
# Out:
#          id create_date       subs_id  \
# 0         1  2022-02-12  100071156888
# 1         3  2022-04-12  100056305839
# 2         4  2022-08-31  100034687577
# 3         5  2022-08-02  100061132577
# 4         6  2022-11-01  100060041431
# ...     ...         ...           ...
# 11444  8586  2022-05-23  100041271746
# 11445  8587  2022-05-23  100066896480
# 11446  8588  2022-05-23  100033136764
# 11447  8589  2022-05-23  100077186785
# 11448  8590  2022-05-23  200081681365
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 11444               город ЧЕЛЯБИНСК улица ПОБЕДЫ дом 31В  55.18061   61.46042
# 11445              город ЧЕЛЯБИНСК улица САЛЮТНАЯ дом 52  55.16914   61.43617
# 11446             город ЧЕЛЯБИНСК улица УРАЛЬСКАЯ дом 23  55.12447   61.50254
# 11447               город ЧЕРЕМХОВО улица КИРОВО дом 112  53.16049  103.06209
# 11448            город ЯРОСЛАВЛЬ шоссе ТУТАЕВСКОЕ дом 24  57.67746   39.83770
#
#                                           Yandex_address  \
# 0      Русская улица, 61, Владивосток, Приморский кра...
# 1      улица Адмирала Горшкова, 36, микрорайон Снегов...
# 2      улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 3      улица Адмирала Кузнецова, 66, Владивосток, При...
# 4      улица Адмирала Кузнецова, 74, Владивосток, При...
# ...                                                  ...
# 11444                улица Победы, 37, Челябинск, Россия
# 11445              Салютная улица, 52, Челябинск, Россия
# 11446             Уральская улица, 23, Челябинск, Россия
# 11447  улица Кирова, 112, Черемхово, Иркутская област...
# 11448            Тутаевское шоссе, 24, Ярославль, Россия
#
#                                                   mark_6       Region  nps
# 0                             г Владивасток ул.Руская 61  Владивосток   -1
# 1      Город Владивосток, улица Адмирала Горшкова, до...  Владивосток    1
# 2                   Владивосток , Адмирала Кузнецова 50а  Владивосток   -1
# 3              г. Владивосток. ул. Адмирала Кузнецова 66  Владивосток   -1
# 4                  Г. Владивосток. Ул. Адм. Кузнецова 74  Владивосток   -1
# ...                                                  ...          ...  ...
# 11444                     Челябинск, 40летия Победы, 31в    Челябинск    1
# 11445                             Челябинск, Салютная 52    Челябинск   -1
# 11446                     Г Челябинск улица уральская 23    Челябинск    1
# 11447                   Город Черемхово,улица кирово 112      Иркутск    1
# 11448                      Ярославль Тутаевское шоссе 24    Ярославль    0
#
# [11449 rows x 10 columns]

# %%
df_pivot = df_pivot[['id', 'create_date', 'subs_id', 'address', 'lat', 'lng',
       'Yandex_address',  'nps']]

# %%
df_pivot
# Out:
#          id create_date       subs_id  \
# 0         1  2022-02-12  100071156888
# 1         3  2022-04-12  100056305839
# 2         4  2022-08-31  100034687577
# 3         5  2022-08-02  100061132577
# 4         6  2022-11-01  100060041431
# ...     ...         ...           ...
# 11444  8586  2022-05-23  100041271746
# 11445  8587  2022-05-23  100066896480
# 11446  8588  2022-05-23  100033136764
# 11447  8589  2022-05-23  100077186785
# 11448  8590  2022-05-23  200081681365
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 11444               город ЧЕЛЯБИНСК улица ПОБЕДЫ дом 31В  55.18061   61.46042
# 11445              город ЧЕЛЯБИНСК улица САЛЮТНАЯ дом 52  55.16914   61.43617
# 11446             город ЧЕЛЯБИНСК улица УРАЛЬСКАЯ дом 23  55.12447   61.50254
# 11447               город ЧЕРЕМХОВО улица КИРОВО дом 112  53.16049  103.06209
# 11448            город ЯРОСЛАВЛЬ шоссе ТУТАЕВСКОЕ дом 24  57.67746   39.83770
#
#                                           Yandex_address  nps
# 0      Русская улица, 61, Владивосток, Приморский кра...   -1
# 1      улица Адмирала Горшкова, 36, микрорайон Снегов...    1
# 2      улица Адмирала Кузнецова, 50А, Владивосток, Пр...   -1
# 3      улица Адмирала Кузнецова, 66, Владивосток, При...   -1
# 4      улица Адмирала Кузнецова, 74, Владивосток, При...   -1
# ...                                                  ...  ...
# 11444                улица Победы, 37, Челябинск, Россия    1
# 11445              Салютная улица, 52, Челябинск, Россия   -1
# 11446             Уральская улица, 23, Челябинск, Россия    1
# 11447  улица Кирова, 112, Черемхово, Иркутская област...    1
# 11448            Тутаевское шоссе, 24, Ярославль, Россия    0
#
# [11449 rows x 8 columns]

# %%
df_pivot['subs_id'] = df_pivot['subs_id'].astype(str)
# Out:
# C:\Users\vitaly.flerin\AppData\Local\Temp\ipykernel_2004\3988443689.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pivot['Yandex_address'] = df_pivot['Yandex_address'].astype(str)
# Out:
# C:\Users\vitaly.flerin\AppData\Local\Temp\ipykernel_2004\2314776241.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pivot.dtypes
# Out:
# id                  int64
# create_date        object
# subs_id            object
# address            object
# lat               float64
# lng               float64
# Yandex_address     object
# nps                 int64
# dtype: object

# %%
#data = df_pivot[(df_pivot['Yandex_address'].str.contains('Россия'))]

# %%
#data1 = data[(data['Yandex_address'].str.contains('Россия'))]

# %%
data = df_pivot
data
# Out:
#          id create_date       subs_id  \
# 0         1  2022-02-12  100071156888
# 1         3  2022-04-12  100056305839
# 2         4  2022-08-31  100034687577
# 3         5  2022-08-02  100061132577
# 4         6  2022-11-01  100060041431
# ...     ...         ...           ...
# 11444  8586  2022-05-23  100041271746
# 11445  8587  2022-05-23  100066896480
# 11446  8588  2022-05-23  100033136764
# 11447  8589  2022-05-23  100077186785
# 11448  8590  2022-05-23  200081681365
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 11444               город ЧЕЛЯБИНСК улица ПОБЕДЫ дом 31В  55.18061   61.46042
# 11445              город ЧЕЛЯБИНСК улица САЛЮТНАЯ дом 52  55.16914   61.43617
# 11446             город ЧЕЛЯБИНСК улица УРАЛЬСКАЯ дом 23  55.12447   61.50254
# 11447               город ЧЕРЕМХОВО улица КИРОВО дом 112  53.16049  103.06209
# 11448            город ЯРОСЛАВЛЬ шоссе ТУТАЕВСКОЕ дом 24  57.67746   39.83770
#
#                                           Yandex_address  nps
# 0      Русская улица, 61, Владивосток, Приморский кра...   -1
# 1      улица Адмирала Горшкова, 36, микрорайон Снегов...    1
# 2      улица Адмирала Кузнецова, 50А, Владивосток, Пр...   -1
# 3      улица Адмирала Кузнецова, 66, Владивосток, При...   -1
# 4      улица Адмирала Кузнецова, 74, Владивосток, При...   -1
# ...                                                  ...  ...
# 11444                улица Победы, 37, Челябинск, Россия    1
# 11445              Салютная улица, 52, Челябинск, Россия   -1
# 11446             Уральская улица, 23, Челябинск, Россия    1
# 11447  улица Кирова, 112, Черемхово, Иркутская област...    1
# 11448            Тутаевское шоссе, 24, Ярославль, Россия    0
#
# [11449 rows x 8 columns]

# %%
map = folium.Map(location = [43.09409 , 131.97061], zoom_start = 2, tiles = 'cartodbpositron' ) # вывод карты

# %%
locations = data[['lat', 'lng']]
elevation = data['nps']
subs = data['subs_id']
locationlist = locations.values.tolist()
#len(locationlist)
#locationlist[7]

# %%
# пример простого вывода, с кластеризацией
map2 = folium.Map(location=[55.62252,37.30162], tiles='CartoDB dark_matter', zoom_start=5)
marker_cluster = MarkerCluster().add_to(map2)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=data['subs_id'][point]).add_to(marker_cluster)
map2

# %%
#добавляем функцию и делим дополнительный столбец с цветом НПС, во фрейм
def regioncolors(counter):
    if counter ['nps'] > 0:
        return 'green'
    elif counter ['nps'] < 0:
        return'red'
    else:
        return('gray')

# %%
data["color"] = data.apply(regioncolors, axis=1)
data.head()
# Out:
# C:\Users\vitaly.flerin\AppData\Local\Temp\ipykernel_2004\993789755.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    id create_date       subs_id  \
# 0   1  2022-02-12  100071156888
# 1   3  2022-04-12  100056305839
# 2   4  2022-08-31  100034687577
# 3   5  2022-08-02  100061132577
# 4   6  2022-11-01  100060041431
#
#                                              address       lat        lng  \
# 0              город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1   город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2  город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3  город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4  город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
#
#                                       Yandex_address  nps  color
# 0  Русская улица, 61, Владивосток, Приморский кра...   -1    red
# 1  улица Адмирала Горшкова, 36, микрорайон Снегов...    1  green
# 2  улица Адмирала Кузнецова, 50А, Владивосток, Пр...   -1    red
# 3  улица Адмирала Кузнецова, 66, Владивосток, При...   -1    red
# 4  улица Адмирала Кузнецова, 74, Владивосток, При...   -1    red

# %%
#итоговый вывод результата
map3 = folium.Map(location=[55.62252,37.30162], tiles='CartoDB dark_matter', zoom_start=5)
marker_cluster = MarkerCluster().add_to(map3)

for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup='ID:'+ ' ' + data['subs_id'][point] + ' ' + data['Yandex_address'][point]  \
        , icon=folium.Icon(color=data['color'][point], icon_color='white', icon='male', angle=0, prefix='fa')).add_to(marker_cluster)  #

map3#.save("map2.html")

# %%
data
# Out:
#          id create_date       subs_id  \
# 0         1  2022-02-12  100071156888
# 1         3  2022-04-12  100056305839
# 2         4  2022-08-31  100034687577
# 3         5  2022-08-02  100061132577
# 4         6  2022-11-01  100060041431
# ...     ...         ...           ...
# 11444  8586  2022-05-23  100041271746
# 11445  8587  2022-05-23  100066896480
# 11446  8588  2022-05-23  100033136764
# 11447  8589  2022-05-23  100077186785
# 11448  8590  2022-05-23  200081681365
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 11444               город ЧЕЛЯБИНСК улица ПОБЕДЫ дом 31В  55.18061   61.46042
# 11445              город ЧЕЛЯБИНСК улица САЛЮТНАЯ дом 52  55.16914   61.43617
# 11446             город ЧЕЛЯБИНСК улица УРАЛЬСКАЯ дом 23  55.12447   61.50254
# 11447               город ЧЕРЕМХОВО улица КИРОВО дом 112  53.16049  103.06209
# 11448            город ЯРОСЛАВЛЬ шоссе ТУТАЕВСКОЕ дом 24  57.67746   39.83770
#
#                                           Yandex_address  nps  color
# 0      Русская улица, 61, Владивосток, Приморский кра...   -1    red
# 1      улица Адмирала Горшкова, 36, микрорайон Снегов...    1  green
# 2      улица Адмирала Кузнецова, 50А, Владивосток, Пр...   -1    red
# 3      улица Адмирала Кузнецова, 66, Владивосток, При...   -1    red
# 4      улица Адмирала Кузнецова, 74, Владивосток, При...   -1    red
# ...                                                  ...  ...    ...
# 11444                улица Победы, 37, Челябинск, Россия    1  green
# 11445              Салютная улица, 52, Челябинск, Россия   -1    red
# 11446             Уральская улица, 23, Челябинск, Россия    1  green
# 11447  улица Кирова, 112, Черемхово, Иркутская област...    1  green
# 11448            Тутаевское шоссе, 24, Ярославль, Россия    0   gray
#
# [11449 rows x 9 columns]

# %% [markdown]
# ФИК

# %%
df=data

# %%
ds= df.groupby('color', dropna=False)['lng'].agg(['count','mean'])
ds

# %%
import pandas as pd
import phik
from phik import resources, report

# open fake car insurance data
df = pd.read_csv( resources.fixture('fake_insurance_data.csv.gz') )
df.head()
# Pearson's correlation matrix between numeric variables (pandas functionality)
df.corr()

# get the phi_k correlation matrix between all variables
df.phik_matrix()

# get global correlations based on phi_k correlation matrix
df.global_phik()

# get the significance matrix (expressed as one-sided Z)
# of the hypothesis test of each variable-pair dependency
df.significance_matrix()

# contingency table of two columns
cols = ['mileage','car_size']
df[cols].hist2d()

# normalized residuals of contingency test applied to cols
df[cols].outlier_significance_matrix()

# show the normalized residuals of each variable-pair
df.outlier_significance_matrices()

# generate a phik correlation report and save as test.pdf
report.correlation_report(df, pdf_file_name='test.pdf')
# Out:
# interval columns not set, guessing: ['count', 'mean']
# interval columns not set, guessing: ['count', 'mean']
# interval columns not set, guessing: ['count', 'mean']
# Exception ignored in: <function ZipFile.__del__ at 0x000001A3FE225280>
# Traceback (most recent call last):
#   File "c:\Users\vitaly.flerin\Miniconda3\lib\zipfile.py", line 1816, in __del__
#     self.close()
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# Cell In [196], line 19
#      15 ds.global_phik()
#      17 # get the significance matrix (expressed as one-sided Z)
#      18 # of the hypothesis test of each variable-pair dependency
# ---> 19 ds.significance_matrix()
#      21 # contingency table of two columns
#      22 cols = ['mileage','car_size']
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\phik\significance.py:421, in significance_matrix(df, interval_cols, lambda_, simulation_method, nsim, significance_method, bins, dropna, drop_underflow, drop_overflow, verbose, njobs)
#     415 df_clean, interval_cols_clean = dq_check_nunique_values(
#     416     df, interval_cols, dropna=dropna
#     417 )
#     419 data_binned = bin_data(df_clean, interval_cols_clean, bins=bins)
# --> 421 return significance_from_rebinned_df(
#     422     data_binned,
#     423     lambda_=lambda_,
#     424     simulation_method=simulation_method,
#     425     nsim=nsim,
#     426     significance_method=significance_method,
#     427     dropna=dropna,
#     428     drop_underflow=drop_underflow,
#     429     drop_overflow=drop_overflow,
#     430     njobs=njobs,
#     431 )
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\phik\significance.py:352, in significance_from_rebinned_df(data_binned, lambda_, simulation_method, nsim, significance_method, dropna, drop_underflow, drop_overflow, njobs)
#     350     datahist.columns = datahist.columns.droplevel()
#     351     datahist = datahist.values
# --> 352     pvalue, zvalue = significance_from_hist2d(
#     353         datahist,
#     354         nsim=nsim,
#     355         lambda_=lambda_,
#     356         simulation_method=simulation_method,
#     357         significance_method=significance_method,
#     358         njobs=njobs,
#     359     )
#     360     signifs.append((c0, c1, zvalue))
#     362 if len(signifs) == 0:
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\phik\significance.py:278, in significance_from_hist2d(values, nsim, lambda_, simulation_method, significance_method, njobs)
#     267     pvalue, zvalue = significance_from_chi2_MC(
#     268         chi2,
#     269         values,
#    (...)
#     273         njobs=njobs,
#     274     )
#     275 elif significance_method == "hybrid":
#     276     # low statistics : calculate pvalue and zvalue using h(x|f) and endof
#     277     # high statistics: calculate pvalue and zvalue using chi2-distribution and endof
# --> 278     pvalue, zvalue = significance_from_chi2_hybrid(
#     279         chi2,
#     280         values,
#     281         nsim=nsim,
#     282         lambda_=lambda_,
#     283         simulation_method=simulation_method,
#     284         njobs=njobs,
#     285     )
#     286 else:
#     287     raise NotImplementedError(
#     288         "simulation_method {0:s} is unknown".format(simulation_method)
#     289     )
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\phik\significance.py:216, in significance_from_chi2_hybrid(chi2, values, nsim, lambda_, simulation_method, chi2s, njobs)
#     213 avg_per_bin = values.sum() / values.shape[0] * values.shape[1]
#     215 if avg_per_bin <= 4:
# --> 216     f, endof, lsigma, bw = fit_test_statistic_distribution(chi2s)
#     217     pvalue_h = f * stats.chi2.sf(chi2, endof) + (1 - f) * stats.norm.sf(
#     218         chi2, endof, lsigma
#     219     )
#     220 else:
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\phik\significance.py:70, in fit_test_statistic_distribution(chi2s, nbins)
#      67 xhist = xbounds[:-1] + np.diff(xbounds) / 2
#      69 initGuess = (1.0,)  # starting value for parameter f
# ---> 70 res = optimize.least_squares(
#      71     gtest, initGuess, bounds=((0.0,), (1,)), args=(xhist, yhist)
#      72 )
#      74 return res.x[0], kmean, lsigma, bw
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:820, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     817 if method == 'trf':
#     818     x0 = make_strictly_feasible(x0, lb, ub)
# --> 820 f0 = fun_wrapped(x0)
#     822 if f0.ndim != 1:
#     823     raise ValueError("`fun` must return at most 1-d array_like. "
#     824                      "f0.shape: {0}".format(f0.shape))
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:815, in least_squares.<locals>.fun_wrapped(x)
#     814 def fun_wrapped(x):
# --> 815     return np.atleast_1d(fun(x, *args, **kwargs))
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\phik\significance.py:57, in fit_test_statistic_distribution.<locals>.gtest(p, x, y)
#      56 def gtest(p, x, y):
# ---> 57     f = ffunc(x, *p)
#      58     ll = f - special.xlogy(y, f) + special.gammaln(y + 1)
#      59     return np.sqrt(ll)
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\phik\significance.py:54, in fit_test_statistic_distribution.<locals>.<lambda>(x, f)
#      51 def myfunc(x, N, f, k, sigma):
#      52     return N * (f * stats.chi2.pdf(x, k) + (1 - f) * stats.norm.pdf(x, k, sigma))
# ---> 54 ffunc = lambda x, f: myfunc(x, nsim * bw, f, kmean, lsigma)
#      56 def gtest(p, x, y):
#      57     f = ffunc(x, *p)
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\phik\significance.py:52, in fit_test_statistic_distribution.<locals>.myfunc(x, N, f, k, sigma)
#      51 def myfunc(x, N, f, k, sigma):
# ---> 52     return N * (f * stats.chi2.pdf(x, k) + (1 - f) * stats.norm.pdf(x, k, sigma))
#
# File c:\Users\vitaly.flerin\Miniconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2085, in rv_continuous.pdf(self, x, *args, **kwds)
#    2083 args = tuple(map(asarray, args))
#    2084 dtyp = np.find_common_type([x.dtype, np.float64], [])
# -> 2085 x = np.asarray((x - loc)/scale, dtype=dtyp)
#    2086 cond0 = self._argcheck(*args) & (scale > 0)
#    2087 cond1 = self._support_mask(x, *args) & (scale > 0)
#
# FloatingPointError: divide by zero encountered in true_divide

# %%
https://betterprogramming.pub/this-library-can-analyze-data-interactively-like-excel-d1d89fe80a5a
import dtale
import pandas as pd
data = dtale.show(data)
data
# Out:
#   Cell In [119], line 1
#     https://betterprogramming.pub/this-library-can-analyze-data-interactively-like-excel-d1d89fe80a5a
#           ^
# SyntaxError: invalid syntax

# %%
https://betterprogramming.pub/this-library-can-analyze-data-interactively-like-excel-d1d89fe80a5a
import dtale
import pandas as pd
data = dtale.show(data)
data

# %%
import pandas as pd
import pandas_profiling
data= pd.read_excel(r"C:\Users\vitaly.flerin\Desktop\05 Ad hoc\2022-12-01_гео\yan_1.xlsx")
data = pandas_profiling.ProfileReport(data)
data.to_file("my_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
import sweetviz as sw
analyze_report = sw.analyze(data)
analyze_report.show_html('ouput.html', open_browser=True)
'''unique_numbers = list(set(data['subs_id']))
unique_numbers
len(unique_numbers)
len(data['subs_id'])'''

# %% [markdown]
# подходы

# %%
#%%https://stackoverflow.com/questions/56842575/how-to-display-averages-instead-of-counts-on-folium-markerclusters
import json
import folium
from folium import Marker
from folium.plugins import MarkerCluster
from jinja2 import Template


class MarkerWithProps(Marker):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
        var {{this.get_name()}} = L.marker(
            [{{this.location[0]}}, {{this.location[1]}}],
            {
                icon: new L.Icon.Default(),
                {%- if this.draggable %}
                draggable: true,
                autoPan: true,
                {%- endif %}
                {%- if this.props %}
                props : {{ this.props }} 
                {%- endif %}
                }
            )
            .addTo({{this._parent.get_name()}});
        {% endmacro %}
        """)
    def __init__(self, location, popup=None, tooltip=None, icon=None,
                 draggable=False, props = None ):
        super(MarkerWithProps, self).__init__(location=location,popup=popup,tooltip=tooltip,icon=icon,draggable=draggable)
        self.props = json.loads(json.dumps(props))    



map = folium.Map(location=[55.62252,37.30162], tiles='CartoDB dark_matter', zoom_start=5)

marker_data =(
    {
        'location':[40.67, -73.94],
        'population': 200     
    },
    {
        'location':[44.67, -73.94],
        'population': 300     
    }
)

icon_create_function = '''
    function(cluster) {
        var markers = cluster.getAllChildMarkers();
        var sum = 0;
        for (var i = 0; i < markers.length; i++) {
            sum += markers[i].options.props.population;
        }
        var avg = sum/cluster.getChildCount();

        return L.divIcon({
             html: '<b>' + avg + '</b>',
             className: 'marker-cluster marker-cluster-small',
             iconSize: new L.Point(20, 20)
        });
    }
'''

marker_cluster = MarkerCluster(icon_create_function=icon_create_function)

for marker_item in marker_data:
    marker = MarkerWithProps(
        location=marker_item['location'],
        props = { 'population': marker_item['population']}
    )
    marker.add_to(marker_cluster)

marker_cluster.add_to(map)    

#m.save(os.path.join('results', '1000_MarkerCluster0.html'))
map

# %%
n = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# add marker one by one on the map
for i in range(0,len(data)):
    html=f"""
        <h1> {data.iloc[i]['subs_id']}</h1>
        <p>You can use any html here! Let's do a list:</p>
        <ul>
            <li>Item 1</li>
            <li>Item 2</li>
        </ul>
        </p>
        <p>And that's a <a href="https://www.python-graph-gallery.com">link</a></p>
        """
    iframe = folium.IFrame(html=html, width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        location=[data.iloc[i]['lat'], data.iloc[i]['lng']],
        popup=popup,
        icon=folium.DivIcon(html=f"""
            <div><svg>
                <circle cx="10" cy="10" r="10" fill="#69b3a2" opacity=".4"/>
                <rect x="35", y="35" width="30" height="30", fill="red", opacity=".3" 
            </svg></div>""")
    ).add_to(n)

# Show the map again
n

# %%
n = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# add marker one by one on the map
for i in range(0,len(data)):
   folium.Marker(
      location=[data.iloc[i]['lat'], data.iloc[i]['lng']],
      popup=data.iloc[i]['address'],
      icon=folium.DivIcon(html=f"""<div style="font-family: courier new; color: blue">{data.iloc[i]['address']}</div>""")
   ).add_to(n)
n   

# Show the map again

# %%
import folium
from folium.plugins import MarkerCluster


m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)


folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m

# %% [markdown]
# Подход 3, пример

# %%
map = folium.Map(location = [15.4529, 90.797], zoom_start=4)
folium.TileLayer('cartodbdark_matter').add_to(map) # Sets Tile Theme to (Dark Theme)
mc = MarkerCluster()
for index, row in data.iterrows():
   mc.add_child(folium.Marker(location=[str(row['lat']),     str(row['lng'])], tooltip="Put anything you want here!",
   icon=folium.Icon(color="red", icon='info-sign', icon_color='white', clustered_marker=True )))
   folium.Circle(location=[str(row['lat']), str(row['lng'])],   color=data['color'][index], fill=True,  fill_color='Red'  ''', radius=int(row['nps']) * 30''').add_to(map)
map.add_child(mc)   
map#.save('medium_map.html')

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd
df = pd.read_csv('https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-28-2020.csv?raw=true') # Reading in the CSV

# %%
map = folium.Map(location = [15.4529, 90.797], zoom_start=4)
folium.TileLayer('cartodbdark_matter').add_to(map) # Sets Tile Theme to (Dark Theme)
mc = MarkerCluster()
for index, row in df.iterrows():
   mc.add_child(folium.Marker(location=[str(row['Lat']),     str(row['Long_'])], tooltip="Put anything you want here!",
   icon=folium.Icon(color="red", icon="info-sign",      clustered_marker=True)))
   folium.Circle(location=[str(row['Lat']), str(row['Long_'])],   color='Red', fill=True, fill_color='Red',
              radius=int(row['Confirmed']) * 30).add_to(map)
map.add_child(mc)
map.save('medium_map.html') # Saves Map to an HTML File

# %%
df.loc[(df!=0).any(axis=1)]

# %%
import numpy as np
df = df.replace(0, np.nan)
df = df.dropna(how='all', axis=1)
df = df.replace(np.nan, 0)

# %%
df= df[df['Lat'] != 0]

# %%
df= df[df['Long_'] != 0]

# %%
df.to_excel('qwre.xlsx')

# %%
#черновик и наработки
'''examp 1'''
latitudes = list(df['lat'])
longitudes = list(df['lng'])
for lat, lng in zip(latitudes, longitudes):
    folium.CircleMarker(location=[lat, lng], radius = 9, fill_color='red' ,  color="gray", fill_opacity = 0.01, icon = folium.Icon(color='green',icon='ok-sign')).add_to(map)
map

'''2'''
map = folium.Map(location=[55.62252,37.30162], zoom_start = 5, tiles = 'cartodbpositron')

for lat, lon, elevation in zip(lat, lon, elevation):
    folium.CircleMarker(location=[lat, lon], radius = 1, popup=str(elevation)+" m", fill_color='red', color="gray", fill_opacity = 0.5).add_to(map)

'''3'''
# рабочий кодYandex_address
lat = data['lat']
lon = data['lng']
elevation = data['nps']
#subs = data['subs_id']

def color_change(elev):
    if(elev > 0):
        return('green')
    elif( elev <0):
        return('red')
    else:
        return('grey')

map = folium.Map(location=[55.62252,37.30162], zoom_start = 4, tiles = 'CartoDB dark_matter')
marker_cluster = MarkerCluster().add_to(map)


for lat, lon, elevation in zip(lat, lon, elevation):
    folium.CircleMarker(location=[lat, lon], radius = 9, popup=(str(elevation)+" NPS"), fill_color=color_change(elevation), color="gray", fill_opacity = 0.9).add_to(marker_cluster)

map.save("map1.html")

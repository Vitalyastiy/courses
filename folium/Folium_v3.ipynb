# %%
import folium 
import pandas as pd
from folium.plugins import MarkerCluster
import pandas as pd
import requests
from xml.etree import ElementTree
import numpy as np
import folium
import numpy as np

# %%
df1= pd.read_excel(r"C:\Users\vitaly.flerin\Desktop\05 Ad hoc\2022-12-01_гео\Результаты гео\summ.xlsx")
df1
# Out:
#           id create_date       subs_id  \
# 0          1  2022-02-12  100071156888
# 1          2  2022-07-27  100072087061
# 2          3  2022-04-12  100056305839
# 3          4  2022-08-31  100034687577
# 4          5  2022-08-02  100061132577
# ...      ...         ...           ...
# 23467  20474  2022-11-25  300013018338
# 23468  20475  2022-11-25      18628155
# 23469  20476  2022-11-25      61714618
# 23470  20477  2022-11-25  100046002879
# 23471  20478  2022-11-25      61987476
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1                        город ВЛАДИВОСТОК улица  дом 10   0.00000    0.00000
# 2       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# ...                                                  ...       ...        ...
# 23467  район ЧЕХОВСКИЙ деревня ГОРЕЛОВО улица БУЛЫЧЕВ...  55.10832   37.26302
# 23468   район ШЕБЕКИНСКИЙ село ВОЗНЕСЕНОВКА улица ПОБЕДЫ  50.41581   37.01111
# 23469         село КРАСНОСЕЛЬСКОЕ улица МОЛОДЕЖНАЯ дом 5  45.29171   39.15944
# 23470             село ПЕТРОВСКОЕ улица МОЛОДЕЖНАЯ дом 4  52.61936   40.22959
# 23471  станица КАБАРДИНСКАЯ улица ТРУДОВАЯ город АПШЕ...  44.51195   39.48162
#
#                                           Yandex_address
# 0      Русская улица, 61, Владивосток, Приморский кра...
# 1                                                      0
# 2      улица Адмирала Горшкова, 36, микрорайон Снегов...
# 3      улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 4      улица Адмирала Кузнецова, 66, Владивосток, При...
# ...                                                  ...
# 23467  Булычёвская улица, 22, деревня Горелово, город...
# 23468  улица Победы, село Вознесеновка, Шебекинский г...
# 23469  Молодёжная улица, 5, село Красносельское, Динс...
# 23470  Молодёжная улица, 4, село Петровское, Петровск...
# 23471  Трудовая улица, 13, станица Кабардинская, Каба...
#
# [23472 rows x 7 columns]

# %%
df1['Yandex_address'] = df1['Yandex_address'].astype(str)

# %%
df1 = df1[(df1['Yandex_address'].str.contains('Россия'))]
df1
# Out:
#           id create_date       subs_id  \
# 0          1  2022-02-12  100071156888
# 2          3  2022-04-12  100056305839
# 3          4  2022-08-31  100034687577
# 4          5  2022-08-02  100061132577
# 5          6  2022-11-01  100060041431
# ...      ...         ...           ...
# 23467  20474  2022-11-25  300013018338
# 23468  20475  2022-11-25      18628155
# 23469  20476  2022-11-25      61714618
# 23470  20477  2022-11-25  100046002879
# 23471  20478  2022-11-25      61987476
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 2       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 5      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 23467  район ЧЕХОВСКИЙ деревня ГОРЕЛОВО улица БУЛЫЧЕВ...  55.10832   37.26302
# 23468   район ШЕБЕКИНСКИЙ село ВОЗНЕСЕНОВКА улица ПОБЕДЫ  50.41581   37.01111
# 23469         село КРАСНОСЕЛЬСКОЕ улица МОЛОДЕЖНАЯ дом 5  45.29171   39.15944
# 23470             село ПЕТРОВСКОЕ улица МОЛОДЕЖНАЯ дом 4  52.61936   40.22959
# 23471  станица КАБАРДИНСКАЯ улица ТРУДОВАЯ город АПШЕ...  44.51195   39.48162
#
#                                           Yandex_address
# 0      Русская улица, 61, Владивосток, Приморский кра...
# 2      улица Адмирала Горшкова, 36, микрорайон Снегов...
# 3      улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 4      улица Адмирала Кузнецова, 66, Владивосток, При...
# 5      улица Адмирала Кузнецова, 74, Владивосток, При...
# ...                                                  ...
# 23467  Булычёвская улица, 22, деревня Горелово, город...
# 23468  улица Победы, село Вознесеновка, Шебекинский г...
# 23469  Молодёжная улица, 5, село Красносельское, Динс...
# 23470  Молодёжная улица, 4, село Петровское, Петровск...
# 23471  Трудовая улица, 13, станица Кабардинская, Каба...
#
# [23132 rows x 7 columns]

# %%
df_np = pd.read_csv(r"C:\Users\vitaly.flerin\Desktop\05 Ad hoc\2022-12-01_гео\result_2.csv",sep=',' , encoding='cp1251' )
df_np
# Out:
#        create_date       subs_id  \
# 0       2022-09-14  300002341055
# 1       2022-11-03  200102964910
# 2       2022-07-19      46541013
# 3       2022-04-04      62082420
# 4       2022-01-31  200073346869
# ...            ...           ...
# 181747  2022-04-18      59625814
# 181748  2022-07-21  200052041366
# 181749  2022-10-11  200085763712
# 181750  2022-01-26      51783545
# 181751  2022-02-18  200080096773
#
#                                                    mark_6          Region  nps
# 0       У вас есть запись разговоров вот и смотрите ни...           Пермь   -1
# 1       На все вопросы сотрудники отвечали доступно, п...       Сыктывкар    1
# 2       Ростовская обл цимлянский район ст красноярска...  Ростов на Дону   -1
# 3                                        Спасибо вам тоже       Волгоград    1
# 4       Частный дом в Калужской обл. Перемышльского ро...          Калуга   -1
# ...                                                   ...             ...  ...
# 181747                                          Благодарю       Волгоград    1
# 181748                         Иногда по всему Ульяновску       Ульяновск   -1
# 181749                                   Посёлок Батецкий      В.Новгород   -1
# 181750                     Добринский район Липецкой обл.          Липецк   -1
# 181751                           Хорошая связь и интернет       Ярославль    1
#
# [181752 rows x 5 columns]

# %%
df_pivot = pd.merge(df1, df_np, how = 'inner', left_on = ['create_date', 'subs_id'], right_on = ['create_date', 'subs_id'])
df_pivot
#df_np['create_date'] = df['create_date'].astype(object)
# Out:
#           id create_date       subs_id  \
# 0          1  2022-02-12  100071156888
# 1          3  2022-04-12  100056305839
# 2          4  2022-08-31  100034687577
# 3          5  2022-08-02  100061132577
# 4          6  2022-11-01  100060041431
# ...      ...         ...           ...
# 23127  20474  2022-11-25  300013018338
# 23128  20475  2022-11-25      18628155
# 23129  20476  2022-11-25      61714618
# 23130  20477  2022-11-25  100046002879
# 23131  20478  2022-11-25      61987476
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 23127  район ЧЕХОВСКИЙ деревня ГОРЕЛОВО улица БУЛЫЧЕВ...  55.10832   37.26302
# 23128   район ШЕБЕКИНСКИЙ село ВОЗНЕСЕНОВКА улица ПОБЕДЫ  50.41581   37.01111
# 23129         село КРАСНОСЕЛЬСКОЕ улица МОЛОДЕЖНАЯ дом 5  45.29171   39.15944
# 23130             село ПЕТРОВСКОЕ улица МОЛОДЕЖНАЯ дом 4  52.61936   40.22959
# 23131  станица КАБАРДИНСКАЯ улица ТРУДОВАЯ город АПШЕ...  44.51195   39.48162
#
#                                           Yandex_address  \
# 0      Русская улица, 61, Владивосток, Приморский кра...
# 1      улица Адмирала Горшкова, 36, микрорайон Снегов...
# 2      улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 3      улица Адмирала Кузнецова, 66, Владивосток, При...
# 4      улица Адмирала Кузнецова, 74, Владивосток, При...
# ...                                                  ...
# 23127  Булычёвская улица, 22, деревня Горелово, город...
# 23128  улица Победы, село Вознесеновка, Шебекинский г...
# 23129  Молодёжная улица, 5, село Красносельское, Динс...
# 23130  Молодёжная улица, 4, село Петровское, Петровск...
# 23131  Трудовая улица, 13, станица Кабардинская, Каба...
#
#                                                   mark_6              Region  \
# 0                             г Владивасток ул.Руская 61         Владивосток
# 1      Город Владивосток, улица Адмирала Горшкова, до...         Владивосток
# 2                   Владивосток , Адмирала Кузнецова 50а         Владивосток
# 3              г. Владивосток. ул. Адмирала Кузнецова 66         Владивосток
# 4                  Г. Владивосток. Ул. Адм. Кузнецова 74         Владивосток
# ...                                                  ...                 ...
# 23127  Чеховский район, д. Горелово, ул. Булычевская, 22              Москва
# 23128     Шебекинский район, с. Вознесеновка, ул. Победы            Белгород
# 23129                Село Красносельское ул Молодёжная 5  Краснодар и Адыгея
# 23130             Село Петровское,улица Молодежная,дом 4                ЯНАО
# 23131  Апшеронске район, станица Кабардинская, ул Тру...  Краснодар и Адыгея
#
#        nps
# 0       -1
# 1        1
# 2       -1
# 3       -1
# 4       -1
# ...    ...
# 23127   -1
# 23128   -1
# 23129   -1
# 23130   -1
# 23131    1
#
# [23132 rows x 10 columns]

# %%
df_pivot = df_pivot[['id', 'create_date', 'subs_id', 'address', 'lat', 'lng', 'Region',
       'Yandex_address',  'nps']]
df_pivot
# Out:
#           id create_date       subs_id  \
# 0          1  2022-02-12  100071156888
# 1          3  2022-04-12  100056305839
# 2          4  2022-08-31  100034687577
# 3          5  2022-08-02  100061132577
# 4          6  2022-11-01  100060041431
# ...      ...         ...           ...
# 23127  20474  2022-11-25  300013018338
# 23128  20475  2022-11-25      18628155
# 23129  20476  2022-11-25      61714618
# 23130  20477  2022-11-25  100046002879
# 23131  20478  2022-11-25      61987476
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 23127  район ЧЕХОВСКИЙ деревня ГОРЕЛОВО улица БУЛЫЧЕВ...  55.10832   37.26302
# 23128   район ШЕБЕКИНСКИЙ село ВОЗНЕСЕНОВКА улица ПОБЕДЫ  50.41581   37.01111
# 23129         село КРАСНОСЕЛЬСКОЕ улица МОЛОДЕЖНАЯ дом 5  45.29171   39.15944
# 23130             село ПЕТРОВСКОЕ улица МОЛОДЕЖНАЯ дом 4  52.61936   40.22959
# 23131  станица КАБАРДИНСКАЯ улица ТРУДОВАЯ город АПШЕ...  44.51195   39.48162
#
#                    Region                                     Yandex_address  \
# 0             Владивосток  Русская улица, 61, Владивосток, Приморский кра...
# 1             Владивосток  улица Адмирала Горшкова, 36, микрорайон Снегов...
# 2             Владивосток  улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 3             Владивосток  улица Адмирала Кузнецова, 66, Владивосток, При...
# 4             Владивосток  улица Адмирала Кузнецова, 74, Владивосток, При...
# ...                   ...                                                ...
# 23127              Москва  Булычёвская улица, 22, деревня Горелово, город...
# 23128            Белгород  улица Победы, село Вознесеновка, Шебекинский г...
# 23129  Краснодар и Адыгея  Молодёжная улица, 5, село Красносельское, Динс...
# 23130                ЯНАО  Молодёжная улица, 4, село Петровское, Петровск...
# 23131  Краснодар и Адыгея  Трудовая улица, 13, станица Кабардинская, Каба...
#
#        nps
# 0       -1
# 1        1
# 2       -1
# 3       -1
# 4       -1
# ...    ...
# 23127   -1
# 23128   -1
# 23129   -1
# 23130   -1
# 23131    1
#
# [23132 rows x 9 columns]

# %%
df_pivot['subs_id'] = df_pivot['subs_id'].astype(str)
# Out:
# C:\Users\vitaly.flerin\AppData\Local\Temp\ipykernel_24556\3988443689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot['subs_id'] = df_pivot['subs_id'].astype(str)

# %%
df_pivot['Yandex_address'] = df_pivot['Yandex_address'].astype(str)
# Out:
# C:\Users\vitaly.flerin\AppData\Local\Temp\ipykernel_24556\2314776241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot['Yandex_address'] = df_pivot['Yandex_address'].astype(str)

# %%
df_pivot.dtypes
# Out:
# id                  int64
# create_date        object
# subs_id            object
# address            object
# lat               float64
# lng               float64
# Region             object
# Yandex_address     object
# nps                 int64
# dtype: object

# %%
#data = df_pivot[(df_pivot['Yandex_address'].str.contains('Россия'))]

# %%
#data1 = data[(data['Yandex_address'].str.contains('Россия'))]

# %%
data = df_pivot
data
# Out:
#           id create_date       subs_id  \
# 0          1  2022-02-12  100071156888
# 1          3  2022-04-12  100056305839
# 2          4  2022-08-31  100034687577
# 3          5  2022-08-02  100061132577
# 4          6  2022-11-01  100060041431
# ...      ...         ...           ...
# 23127  20474  2022-11-25  300013018338
# 23128  20475  2022-11-25      18628155
# 23129  20476  2022-11-25      61714618
# 23130  20477  2022-11-25  100046002879
# 23131  20478  2022-11-25      61987476
#
#                                                  address       lat        lng  \
# 0                  город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1       город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4      город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
# ...                                                  ...       ...        ...
# 23127  район ЧЕХОВСКИЙ деревня ГОРЕЛОВО улица БУЛЫЧЕВ...  55.10832   37.26302
# 23128   район ШЕБЕКИНСКИЙ село ВОЗНЕСЕНОВКА улица ПОБЕДЫ  50.41581   37.01111
# 23129         село КРАСНОСЕЛЬСКОЕ улица МОЛОДЕЖНАЯ дом 5  45.29171   39.15944
# 23130             село ПЕТРОВСКОЕ улица МОЛОДЕЖНАЯ дом 4  52.61936   40.22959
# 23131  станица КАБАРДИНСКАЯ улица ТРУДОВАЯ город АПШЕ...  44.51195   39.48162
#
#                    Region                                     Yandex_address  \
# 0             Владивосток  Русская улица, 61, Владивосток, Приморский кра...
# 1             Владивосток  улица Адмирала Горшкова, 36, микрорайон Снегов...
# 2             Владивосток  улица Адмирала Кузнецова, 50А, Владивосток, Пр...
# 3             Владивосток  улица Адмирала Кузнецова, 66, Владивосток, При...
# 4             Владивосток  улица Адмирала Кузнецова, 74, Владивосток, При...
# ...                   ...                                                ...
# 23127              Москва  Булычёвская улица, 22, деревня Горелово, город...
# 23128            Белгород  улица Победы, село Вознесеновка, Шебекинский г...
# 23129  Краснодар и Адыгея  Молодёжная улица, 5, село Красносельское, Динс...
# 23130                ЯНАО  Молодёжная улица, 4, село Петровское, Петровск...
# 23131  Краснодар и Адыгея  Трудовая улица, 13, станица Кабардинская, Каба...
#
#        nps
# 0       -1
# 1        1
# 2       -1
# 3       -1
# 4       -1
# ...    ...
# 23127   -1
# 23128   -1
# 23129   -1
# 23130   -1
# 23131    1
#
# [23132 rows x 9 columns]

# %%
map = folium.Map(location = [43.09409 , 131.97061], zoom_start = 2, tiles = 'cartodbpositron' ) # вывод карты

# %%
locations = data[['lat', 'lng']]
elevation = data['nps']
subs = data['subs_id']
locationlist = locations.values.tolist()
#len(locationlist)
#locationlist[7]

# %%
# пример простого вывода, с кластеризацией
map2 = folium.Map(location=[55.62252,37.30162], tiles='CartoDB dark_matter', zoom_start=5)
marker_cluster = MarkerCluster().add_to(map2)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=data['subs_id'][point]).add_to(marker_cluster)
map2

# %%
#добавляем функцию и делим дополнительный столбец с цветом НПС, во фрейм
def regioncolors(counter):
    if counter ['nps'] > 0:
        return 'green'
    elif counter ['nps'] < 0:
        return'red'
    else:
        return('gray')

# %%
data["color"] = data.apply(regioncolors, axis=1)
data.head()
# Out:
#    id create_date       subs_id  \
# 0   1  2022-02-12  100071156888
# 1   3  2022-04-12  100056305839
# 2   4  2022-08-31  100034687577
# 3   5  2022-08-02  100061132577
# 4   6  2022-11-01  100060041431
#
#                                              address       lat        lng  \
# 0              город ВЛАДИВАСТОК улица РУСКАЯ дом 61  43.17087  131.93081
# 1   город ВЛАДИВОСТОК улица АДМИРАЛА ГОРШКОВА дом 36  43.16610  131.95263
# 2  город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом...  43.12374  131.95085
# 3  город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 66  43.11973  131.94525
# 4  город ВЛАДИВОСТОК улица АДМИРАЛА КУЗНЕЦОВА дом 74  43.11626  131.94479
#
#         Region                                     Yandex_address  nps  color
# 0  Владивосток  Русская улица, 61, Владивосток, Приморский кра...   -1    red
# 1  Владивосток  улица Адмирала Горшкова, 36, микрорайон Снегов...    1  green
# 2  Владивосток  улица Адмирала Кузнецова, 50А, Владивосток, Пр...   -1    red
# 3  Владивосток  улица Адмирала Кузнецова, 66, Владивосток, При...   -1    red
# 4  Владивосток  улица Адмирала Кузнецова, 74, Владивосток, При...   -1    red

# %%
#итоговый вывод результата
map3 = folium.Map(location=[55.62252,37.30162], tiles='CartoDB dark_matter', zoom_start=5)
marker_cluster = MarkerCluster().add_to(map3)

for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup='ID:'+ ' ' + data['subs_id'][point] + ' ' + data['Yandex_address'][point]  \
        , icon=folium.Icon(color=data['color'][point], icon_color='white', icon='male', angle=0, prefix='fa')).add_to(marker_cluster)  #

map3#.save("map2.html")

# %%
#черновик и наработки
'''examp 1'''
latitudes = list(df['lat'])
longitudes = list(df['lng'])
for lat, lng in zip(latitudes, longitudes):
    folium.CircleMarker(location=[lat, lng], radius = 9, fill_color='red' ,  color="gray", fill_opacity = 0.01, icon = folium.Icon(color='green',icon='ok-sign')).add_to(map)
map

'''2'''
map = folium.Map(location=[55.62252,37.30162], zoom_start = 5, tiles = 'cartodbpositron')

for lat, lon, elevation in zip(lat, lon, elevation):
    folium.CircleMarker(location=[lat, lon], radius = 1, popup=str(elevation)+" m", fill_color='red', color="gray", fill_opacity = 0.5).add_to(map)

'''3'''
# рабочий кодYandex_address
lat = data['lat']
lon = data['lng']
elevation = data['nps']
#subs = data['subs_id']

def color_change(elev):
    if(elev > 0):
        return('green')
    elif( elev <0):
        return('red')
    else:
        return('grey')

map = folium.Map(location=[55.62252,37.30162], zoom_start = 4, tiles = 'CartoDB dark_matter')
marker_cluster = MarkerCluster().add_to(map)


for lat, lon, elevation in zip(lat, lon, elevation):
    folium.CircleMarker(location=[lat, lon], radius = 9, popup=(str(elevation)+" NPS"), fill_color=color_change(elevation), color="gray", fill_opacity = 0.9).add_to(marker_cluster)

map.save("map1.html")

# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitalyastiy/libraries/blob/main/pandas/.Pandas_%D1%80%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B5%20%D1%82%D0%B5%D1%82%D1%80%D0%B0%D0%B4%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Рабочий лист 1.

# %% [markdown]
# 1
# ютуб: https://www.youtube.com/watch?v=vfpWsqg1QH0

# %%
import pandas as pd
import numpy as np

# %%
df1 = 'https://github.com/Vitalyastiy/libraries/blob/main/pandas/diabetes.csv?raw=true'

# %%
df=pd.read_csv(df1)

# %%
 df=pd.Series(df.columns)

# %%
df.info()

# %%
df.describe ()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df[['BMI', 'Insulin']]= df[['BMI', 'Insulin']].replace(0, np.nan) #заменяем ноль на пусто

# %%
df.isna().mean()

# %%
df.Outcome.value_counts().plot.pie()

# %%
df.Age.plot.hist(bins= 45)

# %%
df.Age.value_counts(ascending=False)

# %% [markdown]
# Гистограмка - https://www.codecamp.ru/blog/pandas-histogram/

# %%
df.Insulin.plot.hist(bins = 30)

# %%
df.hist (column='Insulin',  bins= 20, grid= True , rwidth= .9 , color='purple')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b81c11dd0>]],
#       dtype=object)

# %% [markdown]
# #Рабочий лист 2.

# %% [markdown]
# Анализ pandas
# https://blog.skillfactory.ru/kak-nachat-analizirovat-dannye-v-pandas-pervye-shagi/

# %%
import pandas as pd
df = pd.read_csv('2019.csv') 
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#создать датафрейм через словарь
my_df = pd.DataFrame({'id': [1, 2, 3],
                      'name': ['Bob', 'Alice', 'Scott'],
                      'age': [21, 15, 30]})
my_df

# %%
#вложенные списки
df1 = pd.DataFrame([[1,'Bob', 21], 
[2,'Alice', 15], 
[3,'Scott', 30]], 
columns = ['id','name', 'age'])

# %%
df.shape
#размер фрейма

# %%
df.shape[1]
df.shape[0]

# %%
df.rename(columns = {'Overall rank':'Место в рейтинге', 
'Country or region':'Страна или регион', 
'Score':'Баллы', 'GDP per capita':'ВВП на душу населения', 
'Social support':'Социальная поддержка', 
'Healthy life expectancy':'Ожидаемая продолжительность здоровой жизни', 
'Freedom to make life choices':'Свобода жизненных выборов', 
'Generosity':'Щедрость', 'Perceptions of corruption':'Восприятие коррупции'},
inplace = True)
df.head()
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                 1           Finland  7.769                  1.340
# 1                 2           Denmark  7.600                  1.383
# 2                 3            Norway  7.554                  1.488
# 3                 4           Iceland  7.494                  1.380
# 4                 5       Netherlands  7.488                  1.396
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 0                 1.587                                       0.986
# 1                 1.573                                       0.996
# 2                 1.582                                       1.028
# 3                 1.624                                       1.026
# 4                 1.522                                       0.999
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 0                      0.596     0.153                 0.393
# ...

# %%
df.describe()
# Out:
#        Место в рейтинге       Баллы  ВВП на душу населения  \
# count        156.000000  156.000000             156.000000
# mean          78.500000    5.407096               0.905147
# std           45.177428    1.113120               0.398389
# min            1.000000    2.853000               0.000000
# 25%           39.750000    4.544500               0.602750
# 50%           78.500000    5.379500               0.960000
# 75%          117.250000    6.184500               1.232500
# max          156.000000    7.769000               1.684000
#
#        Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# count            156.000000                                  156.000000
# mean               1.208814                                    0.725244
# std                0.299191                                    0.242124
# min                0.000000                                    0.000000
# ...

# %%
#срез
df[['Баллы', 'Щедрость']]

# %%
#срез по наименованию
df.loc[:, 'Свобода жизненных выборов' : 'Восприятие коррупции']

# %%
#iloc срез по строкам и столбцам
df.iloc[0:10, 1:3]
# Out:
#   Страна или регион  Баллы
# 0           Finland  7.769
# 1           Denmark  7.600
# 2            Norway  7.554
# 3           Iceland  7.494
# 4       Netherlands  7.488
# 5       Switzerland  7.480
# 6            Sweden  7.343
# 7       New Zealand  7.307
# 8            Canada  7.278
# 9           Austria  7.246

# %%
# перевести в список столбец/наименования столбцов
#df['Баллы'].tolist()
df.columns.tolist()
# Out:
# ['Место в рейтинге',
#  'Страна или регион',
#  'Баллы',
#  'ВВП на душу населения',
#  'Социальная поддержка',
#  'Ожидаемая продолжительность здоровой жизни',
#  'Свобода жизненных выборов',
#  'Щедрость',
#  'Восприятие коррупции']

# %%
df
# Out:
#      Место в рейтинге         Страна или регион  Баллы  ВВП на душу населения  \
# 0                   1                   Finland  7.769                  1.340
# 1                   2                   Denmark  7.600                  1.383
# 2                   3                    Norway  7.554                  1.488
# 3                   4                   Iceland  7.494                  1.380
# 4                   5               Netherlands  7.488                  1.396
# ..                ...                       ...    ...                    ...
# 151               152                    Rwanda  3.334                  0.359
# 152               153                  Tanzania  3.231                  0.476
# 153               154               Afghanistan  3.203                  0.350
# 154               155  Central African Republic  3.083                  0.026
# 155               156               South Sudan  2.853                  0.306
#
# ...

# %%
# add new column/line
df['group'] = df['Баллы'] - df['Щедрость']

# %%
new_row = {'Место в рейтинге': 100, 
'Страна или регион': 'Country', 
'Баллы': 100}
df = df.append(new_row, ignore_index=True)

# %%
#filt
df[df['Место в рейтинге']==100]
# Out:
#      Место в рейтинге Страна или регион    Баллы  ВВП на душу населения  \
# 99                100             Nepal    4.913                  0.446
# 156               100           Country  100.000                    NaN
#
#      Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 99                  1.226                                       0.677
# 156                   NaN                                         NaN
#
#      Свобода жизненных выборов  Щедрость  Восприятие коррупции  group
# 99                       0.439     0.285                 0.089  4.628
# 156                        NaN       NaN                   NaN    NaN

# %%
#добавить сумму снизу
df1 = df.append(df.sum(axis = 0), ignore_index = True)
df1
# Out:
#      Место в рейтинге                                  Страна или регион  \
# 0                   1                                            Finland
# 1                   2                                            Denmark
# 2                   3                                             Norway
# 3                   4                                            Iceland
# 4                   5                                        Netherlands
# ..                ...                                                ...
# 153               154                                        Afghanistan
# 154               155                           Central African Republic
# 155               156                                        South Sudan
# 156               100                                            Country
# 157             12346  FinlandDenmarkNorwayIcelandNetherlandsSwitzerl...
#
#        Баллы  ВВП на душу населения  Социальная поддержка  \
# ...

# %% [markdown]
# в параметрах обязательно нужно указать axis = 1, который показывает, что мы удаляем именно столбец, а не строку.
#
# Соответственно, задав параметр axis = 0, можно удалить любую строку из датафрейма

# %%
df = df.drop(['group'], axis = 1)
df

# %%
df1 = df.drop(df.shape[0]-1, axis = 0)

# %%
#уникальные значения
df['Страна или регион'].unique()

# %%
#подсчет количества значений
len(df['Страна или регион'].unique())
# Out:
# 156
